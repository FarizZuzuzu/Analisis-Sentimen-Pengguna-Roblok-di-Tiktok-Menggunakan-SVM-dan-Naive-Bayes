# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DRIVE_PATH = '/content/drive/MyDrive/SKRIPSI_Septidiana'

# Pastikan direktori ada
import os
os.makedirs(DRIVE_PATH, exist_ok=True)

# Definisikan path untuk data mentah setelah scraping
RAW_DATA_PATH = f'{DRIVE_PATH}/hasil_tiktok_comments_roblox.csv'

print(f"Direktori Google Drive: {DRIVE_PATH}")
print(f"Path Data Mentah: {RAW_DATA_PATH}")
# Out:
# Direktori Google Drive: /content/drive/MyDrive/SKRIPSI_Septidiana
# Path Data Mentah: /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.csv

# %% [markdown]
# install library

# %%
# apify-client : untuk menjalankan Actor dan mengambil dataset dari Apif
# pandas : untuk mengolah data dan menyimpan CSV/Excel
# openpyxi : engine untuk membuat file Excel •xlsx
# tqam : membuat progress bar di loop
# rich : membuat tampilan output terminal lebih cantik (tabel, warna)

# !pip install apify-client pandas openpyxl tqdm rich

from apify_client import ApifyClient
from tqdm import tqdm
from rich.console import Console
from rich.table import Table
from rich import box
import pandas as pd
# Console rich digunakan untuk menampilkan teks berwarna & tabel
console = Console()
# Out:
# Collecting apify-client
#   Downloading apify_client-3.0.5-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Collecting colorama>=0.4.0 (from apify-client)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting impit~=0.13.0 (from apify-client)
#   Downloading impit-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (10.8.0)
# Requirement already satisfied: pydantic>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.0->apify-client) (2.13.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.4.2)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.11.0->apify-client)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client) (3.18)
# Downloading apify_client-3.0.5-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 5.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading impit-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 50.3 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.3 MB/s eta 0:00:00
# Installing collected packages: impit, dnspython, colorama, email-validator, apify-client
# Successfully installed apify-client-3.0.5 colorama-0.4.6 dnspython-2.8.0 email-validator-2.3.0 impit-0.13.1

# %% [markdown]
# inisialisasi client

# %%
# 1. Inisialisasi Apify Client
# ================================================================
# Menghubungkan script dengan akun Apify menggunakan API Token.
# Tanpa token, Actor tidak bisa dijalankan.
API_TOKEN = "masukkan API dari Apify di sini" # + GANTI TOKEN APIFY KAMU

client = ApifyClient(API_TOKEN)

console.rule("[bold cyan]ê Inisialisasi Client Apify")
# Out:
# ─────────────────────────────────────────── ê Inisialisasi Client Apify ───────────────────────────────────────────

# %% [markdown]
# input actor

# %%
run_input = {
    "commentsPerPost": 99999,         # Maksimal komentar yang akan diambil per video
    "excludePinnedPosts": False,  # False = komentar yang dipin juga ikut diambil
    "maxRepliesPerComment": 3,    # Berapa banyak balasan komentar yang diambil
    "postURLs": [
        "https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1",
        "https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1",
        "https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1",
        "https://www.tiktok.com/@north99_/photo/7583288727443606804?_r=1&image_index=2",
        "https://www.tiktok.com/@obayoman80/video/7604431442508107026?_r=1"
        ],

    "resultsPerPage": 99999         # Jumlah komentar yang diambil per batch
}

console.rule("[bold cyan] Pengaturan Input Scraper")
console.print(run_input)          # Menampilkan input agar mudah dicek
# Out:
# ────────────────────────────────────────────  Pengaturan Input Scraper ────────────────────────────────────────────
# {
#     'commentsPerPost': 99999,
#     'excludePinnedPosts': False,
#     'maxRepliesPerComment': 3,
#     'postURLs': [
#         'https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1',
#         'https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1',
#         'https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1',
#         'https://www.tiktok.com/@north99_/photo/7583288727443606804?_r=1&image_index=2',
#         'https://www.tiktok.com/@obayoman80/video/7604431442508107026?_r=1'
#     ],
#     'resultsPerPage': 99999
# }

# %% [markdown]
# jalankan actor

# %%
# ===================================================================================
# 3. Menjalankan Actor
# ===================================================================================

# Actor TikTok Scraper dijalankan menggunakan -call)
# Script akan menunggu sampai seluruh proses selesai.
console.rule("[bold yellow]  Menjalankan Actor TikTok Scraper")
console.print("Harap tunggu, proses scraping sedang berjalan...")

run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

console.print("[bold green] Actor selesai dijalankan!")
# Out:
# ───────────────────────────────────────   Menjalankan Actor TikTok Scraper ────────────────────────────────────────
# Harap tunggu, proses scraping sedang berjalan...
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:52.629Z ACTOR: Pulling container image of build bj83SbjO8EyAxjRHx from registry.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:52.632Z ACTOR: Creating container.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:52.780Z ACTOR: Starting container.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:52.781Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:53.205Z Running on architecture: x86_64
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:53.206Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/bash -o pipefail -c bash -c "    java         --enable-native-access=ALL-UNNAMED         -cp classes-test:classes-main:lib/*         com.zhiliaoapp.musically.MetaSec         > /dev/null &     node dist/src/entrypoint.js "
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:55.095Z INFO  System info {"apifyVersion":"3.7.0","apifyClientVersion":"2.23.0","crawleeVersion":"3.16.0","osType":"Linux","nodeVersion":"v24.18.0"}
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:56.050Z INFO  CheerioCrawler: Starting the crawler.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:56.815Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Starting the crawler.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:56.826Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:56.940Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:56.946Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:57.242Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:57.243Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.547Z INFO  Scraped 30 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.603Z INFO  Scraped 18 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.650Z INFO  Scraped 3 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.711Z INFO  Scraped 33 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.729Z INFO  Scraped 32 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:58.985Z INFO  Scraped 2 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:59.108Z INFO  Scraped 8 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:56:59.267Z INFO  Scraped 5 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.233Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@obayoman80/video/7604431442508107026?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.237Z WARN  Post not found or is private-- - https://www.tiktok.com/@obayoman80/video/7604431442508107026?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.305Z INFO  Scraped 8 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.365Z INFO  Scraped 2 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.426Z INFO  Scraped 4 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.740Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:00.817Z INFO  Scraped 11 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:01.269Z INFO  Scraped 2 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.139Z INFO  Scraped 17 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.149Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.298Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.397Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.433Z INFO  Scraped 12 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.792Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:02.815Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:03.439Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:03.455Z INFO  Scraped 19 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:03.942Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:04.051Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:04.233Z INFO  Scraped 9 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:04.473Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:04.833Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.066Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.329Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.602Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.660Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.750Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 37/142 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:05.813Z INFO  [Status message]: Scraped 0/5 posts for top-level comments. Total comments scraped: 171.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:06.531Z INFO  Scraped 19 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:06.539Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:06.540Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:06.978Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:07.450Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:07.478Z INFO  Scraped 16 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:07.672Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:07.881Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:07.995Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:08.061Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:08.354Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:08.376Z INFO  Scraped 12 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:08.758Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:09.484Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:09.567Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:09.619Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:09.789Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:10.048Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:10.164Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:10.314Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.183Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.351Z INFO  Scraped 17 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.799Z INFO  Scraped 19 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.829Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.882Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:11.983Z INFO  Scraped 5 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:12.810Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:12.818Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:12.949Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:13.056Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:13.184Z INFO  Scraped 10 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:13.305Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:13.454Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.447Z INFO  Scraped 9 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.537Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.602Z INFO  Scraped 14 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.609Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.662Z INFO  Scraped 12 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.668Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.952Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:14.958Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:15.141Z INFO  Scraped 19 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:15.149Z INFO  Scraped 8 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:15.194Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:15.812Z INFO  [Status message]: Scraped 0/5 posts for top-level comments. Total comments scraped: 193.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.096Z INFO  Scraped 15 new comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.202Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 81/166 pages, 0 failed requests, desired concurrency 11.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.678Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"0","index":0,"batchInfo":{"batchIndex":0,"batchSize":1}}}
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.752Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.942Z INFO  Scraped 44 new comments. --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:16.992Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:17.396Z INFO  Scraped 15 new comments. --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:17.450Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:17.623Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:17.838Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:17.876Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:18.637Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:18.722Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.011Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.054Z INFO  Scraped 10 new comments. --- https://www.tiktok.com/@handa.satya/video/7612131480793255186?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.141Z INFO  Scraped 9 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.145Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.374Z INFO  Scraped 12 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.499Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:19.659Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.170Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.245Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.671Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.845Z INFO  Scraped 15 new comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.855Z INFO  Scraped 14 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.875Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:20.947Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@north99_/video/7583288727443606804?_r=1&image_index=2
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:21.034Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"30","index":1,"batchInfo":{"batchIndex":0,"batchSize":5}}}
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:21.558Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:21.573Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:21.947Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:22.182Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@divaafi_/video/7382584429690096901?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:22.656Z INFO  Scraped 2 new comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> 2026-07-10T15:57:22.665Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@aiindonesiatimes/video/7520670245866982663?_r=1
# Exception in thread Thread-5 (_stream_log):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/apify_client/_streamed_log.py", line 149, in _stream_log
#     for data in log_stream.iter_bytes():
#                 ^^^^^^^^^^^^^^^^^^^^^^^
# impit.TimeoutException: Request timeout (unknown) exceeded.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 125/227 pages, 0 failed requests, desired concurrency 12.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 175/270 pages, 0 failed requests, desired concurrency 13.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 450.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 211/283 pages, 0 failed requests, desired concurrency 13.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 256/293 pages, 0 failed requests, desired concurrency 14.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 306/345 pages, 0 failed requests, desired concurrency 15.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 735.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 327/359 pages, 0 failed requests, desired concurrency 15.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 363/397 pages, 0 failed requests, desired concurrency 16.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 394/426 pages, 0 failed requests, desired concurrency 17.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 434/469 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 455/491 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 499/533 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 539/582 pages, 0 failed requests, desired concurrency 20.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 566/604 pages, 0 failed requests, desired concurrency 20.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 1877.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 1970.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 695/716 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 738/763 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 773/792 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 800/824 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 2684.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 2810.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 3062.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Crawled 953/968 pages, 0 failed requests, desired concurrency 21.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: RUNNING, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 3164.
# [apify.tiktok-comments-scraper runId:jYAb0DA47sk9BiJUi] -> Status: SUCCEEDED, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 3164.
#  Actor selesai dijalankan!

# %% [markdown]
# ambil hasil Scraping

# %%
# =======================================================================
# 4. Mengambil hasil scraping dengan progress bar
#========================================================================

# Setelah Actor selesai, hasilnya disimpan ke Dataset Apify.
# Kita ambil dataset tersebut dan masukkan ke dalam list 'results'.
console.rule("[bold cyan] Mengambil Data dari Dataset")

results = []

# 'run' is already the Run Pydantic model, so its details are directly accessible
# No need to call .get_sync() as 'run' itself holds the details.

dataset_id = run.default_dataset_id

# Auto-detect jumlah item Jika tersedia, Jika tidak pakai estimasi
# → progress bar akan menampilkan estimasi jumlah item
# Access 'item_count' directly from the 'run' object
estimated_total = run.item_count if hasattr(run, 'item_count') and run.item_count is not None else 3000

# Gunakan tqdm untuk menampilkan progress bar saat data diambil
for item in tqdm(client.dataset(dataset_id).iterate_items(),
                 desc="Mengambil data",
                 unit="item",
                 total=estimated_total):
    results.append(item)
# Out:
# ──────────────────────────────────────────  Mengambil Data dari Dataset ───────────────────────────────────────────
# Mengambil data: 4000item [00:01, 2425.02item/s]

# %%
# ===================================================================================
# 5. Menyimpan ke CSV & Excel
# ===================================================================================

# Penyimpanan data dilakukan setelah scraping selesai.
# File akan disimpan dalam dua format: CSV dan Excel (.xlsx)
console.rule("[bold green]* Menyimpan Data ke File")

# Simpan ke RAW_DATA_PATH di Google Drive
csv_file = RAW_DATA_PATH
excel_file = f"{DRIVE_PATH}/hasil_tiktok_comments_roblox.xlsx"

if results:
  df = pd.DataFrame(results)   # mengubah list hasil scraping jadi dataframe

  # Simpan CSV
  df.to_csv(csv_file, index=False, encoding='utf-8-sig')

  # Simpan Excel menggunakan openpyxl sebagai engine
  df.to_excel(excel_file, index=False, engine="openpyxl")

  # Membuat tabel ringkasan menggunakan rich
  table = Table(title="Ringkasan Output", box=box.HEAVY)
  table.add_column("Jenis File", style="cyan" , justify="center")
  table.add_column ("Nama File", style="green")
  table.add_column ("Jumlah Baris", style="yellow", justify="center")

  table.add_row("CSV", csv_file, str(len(df)))
  table.add_row("Excel", excel_file, str(len(df)))

  console.print (table)

else:
  console.print("[bold red] Tidak ada data ditemukan!")
# Out:
# ──────────────────────────────────────────── * Menyimpan Data ke File ─────────────────────────────────────────────
#                                              Ringkasan Output
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Jenis File ┃ Nama File                                                                   ┃ Jumlah Baris ┃
# ┣━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━┫
# ┃    CSV     ┃ /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.csv  ┃     4000     ┃
# ┃   Excel    ┃ /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.xlsx ┃     4000     ┃
# ┗━━━━━━━━━━━━┻━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━━━┛

# %%
# ================================================================================
# 6. Baca kembali CSV untuk verifikasi
# ================================================================================

from IPython.display import display # Untuk menampilkan DataFrame rapi

print("\n Menverifikasi isi dataset...")

data = pd.read_csv(RAW_DATA_PATH) # Membaca dari RAW_DATA_PATH

print("\n=== Informasi Struktur Data ===")
display(data.info()) # Lebih rapi

print("\n=== Contoh 5 Baris Pertama ===")
display(data.head (5))  # Tampil sebagai tabel
# Out:
#  Menverifikasi isi dataset...
#
# === Informasi Struktur Data ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoWebUrl        3999 non-null   object
#  1   submittedVideoUrl  3999 non-null   object
#  2   input              3999 non-null   object
#  3   cid                3999 non-null   float64
#  4   createTime         3999 non-null   float64
#  5   createTimeISO      3999 non-null   object
#  6   text               3951 non-null   object
#  7   diggCount          3999 non-null   float64
#  8   likedByAuthor      3999 non-null   object
#  9   pinnedByAuthor     3164 non-null   object
#  10  repliesToId        876 non-null    float64
#  11  replyCommentTotal  3123 non-null   float64
#  12  uid                3999 non-null   float64
#  13  uniqueId           3999 non-null   object
#  14  avatarThumbnail    3999 non-null   object
#  15  mentions           3999 non-null   object
#  16  detailedMentions   3999 non-null   object
#  17  error              1 non-null      object
#  18  errorCode          1 non-null      object
#  19  url                1 non-null      object
# dtypes: float64(6), object(14)
# memory usage: 625.1+ KB
# None
# === Contoh 5 Baris Pertama ===
#                                          videoWebUrl  \
# 0  https://www.tiktok.com/@aiindonesiatimes/video...
# 1  https://www.tiktok.com/@aiindonesiatimes/video...
# 2  https://www.tiktok.com/@aiindonesiatimes/video...
# 3  https://www.tiktok.com/@aiindonesiatimes/video...
# 4  https://www.tiktok.com/@aiindonesiatimes/video...
#
#                                    submittedVideoUrl  \
# 0  https://www.tiktok.com/@aiindonesiatimes/video...
# 1  https://www.tiktok.com/@aiindonesiatimes/video...
# 2  https://www.tiktok.com/@aiindonesiatimes/video...
# 3  https://www.tiktok.com/@aiindonesiatimes/video...
# 4  https://www.tiktok.com/@aiindonesiatimes/video...
#
#                                                input           cid  \
# 0  https://www.tiktok.com/@aiindonesiatimes/video...  7.522442e+18
# 1  https://www.tiktok.com/@aiindonesiatimes/video...  7.521544e+18
# 2  https://www.tiktok.com/@aiindonesiatimes/video...  7.521375e+18
# 3  https://www.tiktok.com/@aiindonesiatimes/video...  7.522723e+18
# 4  https://www.tiktok.com/@aiindonesiatimes/video...  7.521903e+18
#
#      createTime             createTimeISO  \
# 0  1.751455e+09  2025-07-02T11:16:28.000Z
# 1  1.751246e+09  2025-06-30T01:12:59.000Z
# 2  1.751207e+09  2025-06-29T14:18:50.000Z
# 3  1.751520e+09  2025-07-03T05:27:20.000Z
# 4  1.751329e+09  2025-07-01T00:23:50.000Z
#
#                                                 text  diggCount likedByAuthor  \
# 0       sakura school simulator yg perlu di hapus...     3907.0         False
# 1                       STOP MENYALAHGUNAKAN ROBLOX!     6374.0         False
# 2   siapa sihh yang buat map beginian, perusak otak💔    10889.0         False
# 3  Brookhaven, salon de fiesta, ITU MAP PALING BA...     1926.0         False
# 4  NOOO, JANGAN SAMPE LEWAT FYP EMAKK GUEE, KARNA...     1394.0         False
#
#   pinnedByAuthor  repliesToId  replyCommentTotal           uid  \
# 0          False          NaN               76.0  7.455607e+18
# 1          False          NaN               18.0  6.700686e+18
# 2          False          NaN               36.0  7.387242e+18
# 3          False          NaN               41.0  7.510191e+18
# 4          False          NaN               53.0  7.294257e+18
#
#           uniqueId                                    avatarThumbnail  \
# 0          maiz915  https://p16-common-sign.tiktokcdn-us.com/tos-a...
# 1  garudarevolsyon  https://p19-common-sign.tiktokcdn-us.com/tos-m...
# 2     yahaha_62829  https://p16-common-sign.tiktokcdn-us.com/tos-a...
# 3        iniqila_1  https://p19-common-sign.tiktokcdn-us.com/tos-a...
# 4           qdgo18  https://p19-common-sign.tiktokcdn-us.com/tos-a...
#
#   mentions detailedMentions error errorCode  url
# 0       []               []   NaN       NaN  NaN
# 1       []               []   NaN       NaN  NaN
# 2       []               []   NaN       NaN  NaN
# 3       []               []   NaN       NaN  NaN
# 4       []               []   NaN       NaN  NaN
