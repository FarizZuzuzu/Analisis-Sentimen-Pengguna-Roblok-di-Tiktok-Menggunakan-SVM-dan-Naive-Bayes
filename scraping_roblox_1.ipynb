# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DRIVE_PATH = '/content/drive/MyDrive/SKRIPSI_Septidiana'

# Pastikan direktori ada
import os
os.makedirs(DRIVE_PATH, exist_ok=True)

# Definisikan path untuk data mentah setelah scraping
RAW_DATA_PATH = f'{DRIVE_PATH}/hasil_tiktok_comments_roblox.csv'

print(f"Direktori Google Drive: {DRIVE_PATH}")
print(f"Path Data Mentah: {RAW_DATA_PATH}")
# Out:
# Direktori Google Drive: /content/drive/MyDrive/SKRIPSI_Septidiana
# Path Data Mentah: /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.csv

# %% [markdown]
# install library

# %%
# apify-client : untuk menjalankan Actor dan mengambil dataset dari Apif
# pandas : untuk mengolah data dan menyimpan CSV/Excel
# openpyxi : engine untuk membuat file Excel •xlsx
# tqam : membuat progress bar di loop
# rich : membuat tampilan output terminal lebih cantik (tabel, warna)

# !pip install apify-client pandas openpyxl tqdm rich

from apify_client import ApifyClient
from tqdm import tqdm
from rich.console import Console
from rich.table import Table
from rich import box
import pandas as pd
# Console rich digunakan untuk menampilkan teks berwarna & tabel
console = Console()
# Out:
# Collecting apify-client
#   Downloading apify_client-3.0.5-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Collecting colorama>=0.4.0 (from apify-client)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting impit~=0.13.0 (from apify-client)
#   Downloading impit-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (10.8.0)
# Requirement already satisfied: pydantic>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.0->apify-client) (2.13.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.4.2)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.11.0->apify-client)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client) (3.18)
# Downloading apify_client-3.0.5-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 8.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading impit-0.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 54.3 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.0 MB/s eta 0:00:00
# Installing collected packages: impit, dnspython, colorama, email-validator, apify-client
# Successfully installed apify-client-3.0.5 colorama-0.4.6 dnspython-2.8.0 email-validator-2.3.0 impit-0.13.1

# %% [markdown]
# inisialisasi client

# %%
# 1. Inisialisasi Apify Client
# ================================================================
# Menghubungkan script dengan akun Apify menggunakan API Token.
# Tanpa token, Actor tidak bisa dijalankan.
API_TOKEN = "apify_api_ByjqHnvkXiI6bIbeqUf8yi1VCKvzCH1fWlqQ" # + GANTI TOKEN APIFY KAMU

client = ApifyClient(API_TOKEN)

console.rule("[bold cyan]ê Inisialisasi Client Apify")
# Out:
# ─────────────────────────────────────────── ê Inisialisasi Client Apify ───────────────────────────────────────────

# %% [markdown]
# input actor

# %%
run_input = {
    "commentsPerPost": 99999,         # Maksimal komentar yang akan diambil per video
    "excludePinnedPosts": False,  # False = komentar yang dipin juga ikut diambil
    "maxRepliesPerComment": 3,    # Berapa banyak balasan komentar yang diambil
    "postURLs": [
        "https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1",
        "https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1",
        "https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1",
        "https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1",
        "https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1"
        ],

    "resultsPerPage": 99999         # Jumlah komentar yang diambil per batch
}

console.rule("[bold cyan] Pengaturan Input Scraper")
console.print(run_input)          # Menampilkan input agar mudah dicek
# Out:
# ────────────────────────────────────────────  Pengaturan Input Scraper ────────────────────────────────────────────
# {
#     'commentsPerPost': 99999,
#     'excludePinnedPosts': False,
#     'maxRepliesPerComment': 3,
#     'postURLs': [
#         'https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1',
#         'https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1',
#         'https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1',
#         'https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1',
#         'https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1'
#     ],
#     'resultsPerPage': 99999
# }

# %% [markdown]
# jalankan actor

# %%
# ===================================================================================
# 3. Menjalankan Actor
# ===================================================================================

# Actor TikTok Scraper dijalankan menggunakan -call)
# Script akan menunggu sampai seluruh proses selesai.
console.rule("[bold yellow]  Menjalankan Actor TikTok Scraper")
console.print("Harap tunggu, proses scraping sedang berjalan...")

run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

console.print("[bold green] Actor selesai dijalankan!")
# Out:
# ───────────────────────────────────────   Menjalankan Actor TikTok Scraper ────────────────────────────────────────
# Harap tunggu, proses scraping sedang berjalan...
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:46.789Z ACTOR: Pulling container image of build bj83SbjO8EyAxjRHx from registry.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:46.790Z ACTOR: Creating container.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:46.935Z ACTOR: Starting container.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:46.936Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:47.189Z Running on architecture: x86_64
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:47.190Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/bash -o pipefail -c bash -c "    java         --enable-native-access=ALL-UNNAMED         -cp classes-test:classes-main:lib/*         com.zhiliaoapp.musically.MetaSec         > /dev/null &     node dist/src/entrypoint.js "
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:49.217Z INFO  System info {"apifyVersion":"3.7.0","apifyClientVersion":"2.23.0","crawleeVersion":"3.16.0","osType":"Linux","nodeVersion":"v24.18.0"}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Starting the crawler.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:49.985Z INFO  CheerioCrawler: Starting the crawler.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.659Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.671Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.963Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.967Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.989Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:50.992Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:51.247Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:51.251Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:51.980Z INFO  Scraped 28 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.122Z INFO  [POST] Starting the post scrape.  --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.127Z INFO  [POST] Starting the comments scrape.  --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.154Z INFO  Scraped 4 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.218Z INFO  Scraped 50 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.584Z INFO  Scraped 10 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.593Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"0","index":0,"batchInfo":{"batchIndex":0,"batchSize":5}}}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.805Z INFO  Scraped 31 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:52.986Z INFO  Scraped 31 new comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:53.502Z INFO  Scraped 33 new comments. --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:53.698Z INFO  Scraped 4 new comments. --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:53.927Z INFO  Scraped 21 new comments. --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.221Z INFO  Scraped 7 new comments. --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.249Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.455Z INFO  Scraped 13 new comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.468Z INFO  Scraped 10 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.611Z INFO  Scraped 4 new comments. --- https://www.tiktok.com/@duniaparenting/video/7595468611855174929?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:54.830Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.115Z INFO  Scraped 3 new comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.174Z INFO  Scraped 4 new comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.344Z INFO  Scraped 6 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.684Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.729Z INFO  Scraped 5 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:55.773Z INFO  Scraped 2 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.313Z INFO  Scraped 11 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.689Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.724Z INFO  Scraped 10 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.917Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code: CURLE_RECV_ERROR (56), retrying
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.918Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:27:73) {"id":"M3CR3bCeZuKfo2w","url":"https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1","retryCount":1}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:56.952Z INFO  Scraped 3 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:57.231Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:57.453Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:57.456Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:57.943Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:58.029Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:58.245Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:58.550Z INFO  Scraped 12 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:58.833Z INFO  Scraped 8 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.094Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.096Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.124Z INFO  Scraped 8 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.358Z INFO  Scraped 11 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.893Z INFO  [Status message]: Scraped 0/5 posts for top-level comments. Total comments scraped: 293.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:45:59.900Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:00.139Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:00.157Z INFO  Scraped 13 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 44/203 pages, 0 failed requests, desired concurrency 10.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:00.165Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:00.674Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:00.790Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.056Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.186Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.530Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.601Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code: CURLE_HTTP2 (16), retrying
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.602Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:27:73) {"id":"HLVwwaFWo9mKxLH","url":"https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1","retryCount":1}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.620Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.782Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:01.931Z INFO  Scraped 20 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:02.331Z INFO  Scraped 13 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:02.536Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:02.634Z INFO  Scraped 15 new comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.097Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.102Z INFO  Scraped 6 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.157Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.348Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Failed to send API request with exit code: CURLE_RECV_ERROR (56), retrying
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.349Z     at async sendCurlRequest (file:///home/myuser/dist/src/tools/api/curl-request.js:27:73) {"id":"5uM1zjCgf0D14Gy","url":"https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1","retryCount":1}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.746Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@urns20/video/7578008231730007316?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:03.751Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.326Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.352Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.562Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.578Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.766Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"0","index":0,"batchInfo":{"batchIndex":0,"batchSize":1}}}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.781Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"0","index":0,"batchInfo":{"batchIndex":0,"batchSize":1}}}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:04.965Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:05.274Z INFO  Scraped 11 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:05.462Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:05.736Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:05.992Z INFO  Scraped 16 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:06.146Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:06.152Z INFO  Scraped 8 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:06.161Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:06.540Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:06.551Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:07.130Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:07.176Z INFO  Scraped 1 new comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:07.931Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:07.935Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:08.041Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:08.263Z INFO  Scraped 8 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:08.571Z INFO  Scraped 5 new reply comments. --- https://www.tiktok.com/@fitria1m/video/7530501841197501701?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 345.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:09.893Z INFO  [Status message]: Scraped 0/5 posts for top-level comments. Total comments scraped: 345.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.349Z WARN  Blocked response, retrying... {"attempt":1,"paginationInfo":{"cursor":"0","index":0,"batchInfo":{"batchIndex":0,"batchSize":1}}}
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.400Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.533Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.603Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.670Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.757Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:10.767Z INFO  Scraped 13 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:11.199Z INFO  Scraped 10 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:11.387Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:11.575Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:11.709Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 84/231 pages, 0 failed requests, desired concurrency 11.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:11.884Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:12.098Z INFO  Scraped 17 new comments. --- https://www.tiktok.com/@yayankatty/video/7503455599443610887?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:13.832Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.305Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.405Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.429Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.558Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.807Z INFO  Scraped 4 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:14.832Z INFO  Scraped 7 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:15.633Z INFO  Scraped 3 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:15.640Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:15.673Z INFO  Scraped 13 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:15.781Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:15.788Z INFO  Scraped 20 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:16.872Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:16.941Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:17.047Z INFO  Scraped 1 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> 2026-07-10T15:46:17.157Z INFO  Scraped 2 new reply comments. --- https://www.tiktok.com/@tentanganak.id/video/7514333296797502728?_r=1
# Exception in thread Thread-5 (_stream_log):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/apify_client/_streamed_log.py", line 149, in _stream_log
#     for data in log_stream.iter_bytes():
#                 ^^^^^^^^^^^^^^^^^^^^^^^
# impit.TimeoutException: Request timeout (unknown) exceeded.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 125/232 pages, 0 failed requests, desired concurrency 12.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 172/254 pages, 0 failed requests, desired concurrency 13.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 217/272 pages, 0 failed requests, desired concurrency 14.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 569.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 705.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 322/364 pages, 0 failed requests, desired concurrency 13.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 360/398 pages, 0 failed requests, desired concurrency 14.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 406/442 pages, 0 failed requests, desired concurrency 15.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 440/478 pages, 0 failed requests, desired concurrency 15.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 1564.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 526/557 pages, 0 failed requests, desired concurrency 17.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 561/584 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 0/5 posts for top-level comments. Total comments scraped: 1914.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 623/649 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 660/685 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 683/706 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 1/5 posts for top-level comments. Total comments scraped: 2244.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 731/753 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 763/776 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 813/826 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 860/873 pages, 0 failed requests, desired concurrency 19.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 890/893 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 892/894 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 895/897 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 3/5 posts for top-level comments. Total comments scraped: 2710.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 897/899 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 901/903 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 905/907 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 907/909 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 4/5 posts for top-level comments. Total comments scraped: 2713.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 909/910 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 4/5 posts for top-level comments. Total comments scraped: 2713.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 909/910 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 911/912 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 913/914 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Scraped 4/5 posts for top-level comments. Total comments scraped: 2713.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 914/915 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: RUNNING, Message: Crawled 916/917 pages, 0 failed requests, desired concurrency 18.
# [apify.tiktok-comments-scraper runId:goKRRJfLIYxurvofa] -> Status: SUCCEEDED, Message: Scraped 5/5 posts for top-level comments. Total comments scraped: 2713.
#  Actor selesai dijalankan!

# %% [markdown]
# ambil hasil Scraping

# %%
# =======================================================================
# 4. Mengambil hasil scraping dengan progress bar
#========================================================================

# Setelah Actor selesai, hasilnya disimpan ke Dataset Apify.
# Kita ambil dataset tersebut dan masukkan ke dalam list 'results'.
console.rule("[bold cyan] Mengambil Data dari Dataset")

results = []

# 'run' is already the Run Pydantic model, so its details are directly accessible
# No need to call .get_sync() as 'run' itself holds the details.

dataset_id = run.default_dataset_id

# Auto-detect jumlah item Jika tersedia, Jika tidak pakai estimasi
# → progress bar akan menampilkan estimasi jumlah item
# Access 'item_count' directly from the 'run' object
estimated_total = run.item_count if hasattr(run, 'item_count') and run.item_count is not None else 3000

# Gunakan tqdm untuk menampilkan progress bar saat data diambil
for item in tqdm(client.dataset(dataset_id).iterate_items(),
                 desc="Mengambil data",
                 unit="item",
                 total=estimated_total):
    results.append(item)
# Out:
# ──────────────────────────────────────────  Mengambil Data dari Dataset ───────────────────────────────────────────
# Mengambil data: 3320item [00:01, 2204.64item/s]

# %%
# ===================================================================================
# 5. Menyimpan ke CSV & Excel
# ===================================================================================

# Penyimpanan data dilakukan setelah scraping selesai.
# File akan disimpan dalam dua format: CSV dan Excel (.xlsx)
console.rule("[bold green]* Menyimpan Data ke File")

# Simpan ke RAW_DATA_PATH di Google Drive
csv_file = RAW_DATA_PATH
excel_file = f"{DRIVE_PATH}/hasil_tiktok_comments_roblox.xlsx"

if results:
  df = pd.DataFrame(results)   # mengubah list hasil scraping jadi dataframe

  # Simpan CSV
  df.to_csv(csv_file, index=False, encoding='utf-8-sig')

  # Simpan Excel menggunakan openpyxl sebagai engine
  df.to_excel(excel_file, index=False, engine="openpyxl")

  # Membuat tabel ringkasan menggunakan rich
  table = Table(title="Ringkasan Output", box=box.HEAVY)
  table.add_column("Jenis File", style="cyan" , justify="center")
  table.add_column ("Nama File", style="green")
  table.add_column ("Jumlah Baris", style="yellow", justify="center")

  table.add_row("CSV", csv_file, str(len(df)))
  table.add_row("Excel", excel_file, str(len(df)))

  console.print (table)

else:
  console.print("[bold red] Tidak ada data ditemukan!")
# Out:
# ──────────────────────────────────────────── * Menyimpan Data ke File ─────────────────────────────────────────────
#                                              Ringkasan Output
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Jenis File ┃ Nama File                                                                   ┃ Jumlah Baris ┃
# ┣━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━┫
# ┃    CSV     ┃ /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.csv  ┃     3320     ┃
# ┃   Excel    ┃ /content/drive/MyDrive/SKRIPSI_Septidiana/hasil_tiktok_comments_roblox.xlsx ┃     3320     ┃
# ┗━━━━━━━━━━━━┻━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━━━┛

# %%
# ================================================================================
# 6. Baca kembali CSV untuk verifikasi
# ================================================================================

from IPython.display import display # Untuk menampilkan DataFrame rapi

print("\n Menverifikasi isi dataset...")

data = pd.read_csv(RAW_DATA_PATH) # Membaca dari RAW_DATA_PATH

print("\n=== Informasi Struktur Data ===")
display(data.info()) # Lebih rapi

print("\n=== Contoh 5 Baris Pertama ===")
display(data.head (5))  # Tampil sebagai tabel
# Out:
#  Menverifikasi isi dataset...
#
# === Informasi Struktur Data ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3320 entries, 0 to 3319
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoWebUrl        3320 non-null   object
#  1   submittedVideoUrl  3320 non-null   object
#  2   input              3320 non-null   object
#  3   cid                3320 non-null   int64
#  4   createTime         3320 non-null   int64
#  5   createTimeISO      3320 non-null   object
#  6   text               3282 non-null   object
#  7   diggCount          3320 non-null   int64
#  8   likedByAuthor      3320 non-null   bool
#  9   pinnedByAuthor     2713 non-null   object
#  10  repliesToId        657 non-null    float64
#  11  replyCommentTotal  2663 non-null   float64
#  12  uid                3320 non-null   int64
#  13  uniqueId           3320 non-null   object
#  14  avatarThumbnail    3320 non-null   object
#  15  mentions           3320 non-null   object
#  16  detailedMentions   3320 non-null   object
# dtypes: bool(1), float64(2), int64(4), object(10)
# memory usage: 418.4+ KB
# None
# === Contoh 5 Baris Pertama ===
#                                          videoWebUrl  \
# 0  https://www.tiktok.com/@urns20/video/757800823...
# 1  https://www.tiktok.com/@urns20/video/757800823...
# 2  https://www.tiktok.com/@urns20/video/757800823...
# 3  https://www.tiktok.com/@urns20/video/757800823...
# 4  https://www.tiktok.com/@urns20/video/757800823...
#
#                                    submittedVideoUrl  \
# 0  https://www.tiktok.com/@urns20/video/757800823...
# 1  https://www.tiktok.com/@urns20/video/757800823...
# 2  https://www.tiktok.com/@urns20/video/757800823...
# 3  https://www.tiktok.com/@urns20/video/757800823...
# 4  https://www.tiktok.com/@urns20/video/757800823...
#
#                                                input                  cid  \
# 0  https://www.tiktok.com/@urns20/video/757800823...  7586610602513548053
# 1  https://www.tiktok.com/@urns20/video/757800823...  7597419465815098119
# 2  https://www.tiktok.com/@urns20/video/757800823...  7582433115840217857
# 3  https://www.tiktok.com/@urns20/video/757800823...  7578008755029705493
# 4  https://www.tiktok.com/@urns20/video/757800823...  7596142397765026561
#
#    createTime             createTimeISO                               text  \
# 0  1766395443  2025-12-22T09:24:03.000Z           aku kena scam tadi.... 😕
# 1  1768912071  2026-01-20T12:27:51.000Z      gua juga kena scam sama dia😭😭
# 2  1765422797  2025-12-11T03:13:17.000Z  barusan kenaaa, sakittt bngtt☹️☹️
# 3  1764392674  2025-11-29T05:04:34.000Z           silakan silaturahmi hehe
# 4  1768614770  2026-01-17T01:52:50.000Z           nitip nama akun musang 🙏
#
#    diggCount  likedByAuthor pinnedByAuthor  repliesToId  replyCommentTotal  \
# 0         84           True          False          NaN               20.0
# 1          0          False          False          NaN                0.0
# 2         24           True          False          NaN               12.0
# 3         22           True          False          NaN               33.0
# 4          9          False          False          NaN               36.0
#
#                    uid     uniqueId  \
# 0  7555458152289633288    dewdew141
# 1  6939359081807283202    liiiii__7
# 2  6588751395935469569  princcesrra
# 3  7523086795719853074       urns20
# 4  7193930170087719938   yannn_1515
#
#                                      avatarThumbnail mentions detailedMentions
# 0  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []               []
# 1  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []               []
# 2  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []               []
# 3  https://p19-common-sign.tiktokcdn-us.com/tos-a...       []               []
# 4  https://p19-common-sign.tiktokcdn-us.com/tos-a...       []               []
